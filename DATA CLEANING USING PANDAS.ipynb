# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\ALL DATA SCIENCE\messy_data.csv")
data
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# ...        ...         ...      ...      ...       ...     ...     ...
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06          NaN         87
# ...

# %% [markdown]
# #1. Removal of duplicate rows

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# ...        ...         ...      ...      ...       ...     ...     ...
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06          NaN         87
# ...

# %% [markdown]
# #2. Checking for missing values

# %%
data.isna().sum()
# Out:
# TrnsnID           0
# Data              0
# CusmrID           0
# ProdtID           0
# ProdtName       994
# Qutity            0
# Prize             0
# TtlSales          0
# PaymentType    1439
# CusterAge         0
# dtype: int64

# %%
data=data.fillna(method='ffill')

# %%
data.isna().sum()
# Out:
# TrnsnID        0
# Data           0
# CusmrID        0
# ProdtID        0
# ProdtName      0
# Qutity         0
# Prize          0
# TtlSales       0
# PaymentType    1
# CusterAge      0
# dtype: int64

# %%
data=data.fillna(method='bfill')

# %%
data.isna().sum()
# Out:
# TrnsnID        0
# Data           0
# CusmrID        0
# ProdtID        0
# ProdtName      0
# Qutity         0
# Prize          0
# TtlSales       0
# PaymentType    0
# CusterAge      0
# dtype: int64

# %% [markdown]
# #3 Ensuring the dates are in a consistent format

# %%
data.Data= pd.to_datetime(data.Data, format='mixed', dayfirst=True)

# %%
data.Data
# Out:
# 0       2026-03-17
# 1       2035-01-26
# 2       2035-05-26
# 3       2036-02-28
# 4       2023-04-19
#            ...
# 10095   2027-03-04
# 10096   2025-08-16
# 10097   2026-06-18
# 10098   2034-08-04
# 10099   2029-04-26
# Name: Data, Length: 10000, dtype: datetime64[ns]

# %%
data.head()
# Out:
#    TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402 2026-03-17      991     1045     Boo E       9  167.72   2935.06
# 1     5835 2035-01-26      741     1040    Book J      18  193.27   4386.52
# 2     2123 2035-05-26      933     1062     Bok N       5  126.39   1948.46
# 3     8789 2036-02-28      641     1060    Book I       6   66.98   1757.26
# 4      305 2023-04-19      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0  debit card         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
data
# Out:
#        TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402 2026-03-17      991     1045     Boo E       9  167.72
# 1         5835 2035-01-26      741     1040    Book J      18  193.27
# 2         2123 2035-05-26      933     1062     Bok N       5  126.39
# 3         8789 2036-02-28      641     1060    Book I       6   66.98
# 4          305 2023-04-19      123     1058    Book B      15   33.63
# ...        ...        ...      ...      ...       ...     ...     ...
# 10095     5735 2027-03-04       52     1066    Book G       1  191.41
# 10096     5192 2025-08-16      334     1093     Bok N      -2  186.16
# 10097     5391 2026-06-18      657     1047   Bookk H       5   84.38
# 10098      861 2034-08-04      579     1014     Bok N      19  137.58
# 10099     7271 2029-04-26      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06   debit card         87
# 1       4386.52   debit card         69
# ...

# %% [markdown]
# #4. Renaming columns and Standardising payment type names

# %%
data.rename(columns={'TrnsnID':'Transaction ID', 'Data':'Date', 'CusmrID':'Consumer ID', 'ProdtID':'Product ID', 'Qutity':'Quantity' }, inplace=True)

# %%
data.sample(n=2)
# Out:
#       Transaction ID       Date  Consumer ID  Product ID ProdtName  Quantity  \
# 1545            9719 2025-06-14          872        1054    Book P        -3
# 6885            9555 2023-02-22          886        1088    Book T         4
#
#        Prize  TtlSales  PaymentType  CusterAge
# 1545  153.81    788.08  Credit Card         96
# 6885   46.58   2951.67       paypal         38

# %%
data.rename(columns={'TtlSales':'Total Sales', 'ProdtName': 'Product Name', 'CusterAge':'Customer Age', 'PaymentType':'Payment Type' }, inplace = True)

# %%
data.sample(n=2)
# Out:
#       Transaction ID       Date  Consumer ID  Product ID Product Name  \
# 6505            1773 2036-03-22          891        1018      Bookk H
# 3387            2155 2035-05-17          619        1095       Book T
#
#       Quantity   Prize  Total Sales Payment Type  Customer Age
# 6505        14  157.12      3259.29  Credit Card            17
# 3387         7  106.15      1998.76        Debit            83

# %%
data.rename(columns={'Consumer ID':'Customer ID'}, inplace=True)

# %%
data.sample(n=2)
# Out:
#       Transaction ID       Date  Customer ID  Product ID Product Name  \
# 8221            1961 2030-10-03          792        1002       Book O
# 6481            1674 2033-10-15          344        1090       Book S
#
#       Quantity   Prize  Total Sales Payment Type  Customer Age
# 8221         3  191.91      4336.37       Credit            -7
# 6481        -4   40.12      3315.94  Credit Card            11

# %%
data
# Out:
#        Transaction ID       Date  Customer ID  Product ID Product Name  \
# 0                7402 2026-03-17          991        1045        Boo E
# 1                5835 2035-01-26          741        1040       Book J
# 2                2123 2035-05-26          933        1062        Bok N
# 3                8789 2036-02-28          641        1060       Book I
# 4                 305 2023-04-19          123        1058       Book B
# ...               ...        ...          ...         ...          ...
# 10095            5735 2027-03-04           52        1066       Book G
# 10096            5192 2025-08-16          334        1093        Bok N
# 10097            5391 2026-06-18          657        1047      Bookk H
# 10098             861 2034-08-04          579        1014        Bok N
# 10099            7271 2029-04-26          153        1052       Book T
#
#        Quantity   Prize  Total Sales Payment Type  Customer Age
# ...

# %%
print(data['Product Name'].value_counts().index)
# Out:
# Index(['Boo E', 'Book O', 'Book M', 'Book D', 'Book J', 'Book I', 'Book L',
#        'Book P', 'Book R', 'Book K', 'Book S', 'Book T', 'Book G', 'Bok N',
#        'Bookk H', 'Book F', 'Book A', 'Book B'],
#       dtype='object', name='Product Name')

# %%
data['Product Name'].replace({'Boo E':'Book E','Bok N':'Book N', 'Bookk H':'Book H' }, inplace=True)

# %%
print(data['Payment Type'].value_counts().index)
# Out:
# Index(['Debit', 'Credit', 'Cash', 'debit card', 'Credit Card', 'paypal'], dtype='object', name='Payment Type')

# %%
data['Payment Type'].replace({'Debit':'Debit Card','Credit':'Credit Card','debit card':'Debit card','paypal':'Paypal' }, inplace=True)

# %%
data.head()
# Out:
#    Transaction ID       Date  Customer ID  Product ID Product Name  Quantity  \
# 0            7402 2026-03-17          991        1045       Book E         9
# 1            5835 2035-01-26          741        1040       Book J        18
# 2            2123 2035-05-26          933        1062       Book N         5
# 3            8789 2036-02-28          641        1060       Book I         6
# 4             305 2023-04-19          123        1058       Book B        15
#
#     Prize  Total Sales Payment Type  Customer Age
# 0  167.72      2935.06   Debit card            87
# 1  193.27      4386.52   Debit card            69
# 2  126.39      1948.46         Cash            15
# 3   66.98      1757.26         Cash            22
# 4   33.63      2578.19         Cash            -1

# %%
print(data.Quantity.value_counts().index)
# Out:
# Index([ 0, 14, 17, 10,  3,  1, -2, 19, -4,  4,  8,  5, 11,  2, 18, 16, 15, -5,
#         9,  6,  7, -1, 12, 13, -3],
#       dtype='int64', name='Quantity')

# %%
data.Quantity.replace({-2:2, -4:4,-5:5, -1:1, -3:3}, inplace=True)

# %%
data.Quantity.value_counts()
# Out:
# Quantity
# 2     802
# 4     800
# 1     798
# 3     788
# 5     787
# 0     447
# 14    431
# 17    430
# 10    427
# 19    404
# 8     399
# 11    396
# 18    395
# 16    395
# 15    393
# 9     387
# 6     383
# 7     382
# 12    379
# 13    377
# Name: count, dtype: int64

# %%
data['Customer Age'].value_counts()
# Out:
# Customer Age
#  58    116
#  82    114
# -7     113
#  65    113
#  84    110
#       ...
#  72     74
#  70     74
#  42     71
#  88     65
#  13     62
# Name: count, Length: 110, dtype: int64

# %%
data['Customer Age']=data['Customer Age'].astype(str)

# %%
data['Customer Age']=data['Customer Age'].str.strip("-")

# %%
data['Customer Age'].astype
# Out:
# 0        87
# 1        69
# 2        15
# 3        22
# 4         1
#          ..
# 10095    91
# 10096    50
# 10097    63
# 10098     7
# 10099    77
# Name: Customer Age, Length: 10000, dtype: object

# %%
data
# Out:
#        Transaction ID       Date  Customer ID  Product ID Product Name  \
# 0                7402 2026-03-17          991        1045       Book E
# 1                5835 2035-01-26          741        1040       Book J
# 2                2123 2035-05-26          933        1062       Book N
# 3                8789 2036-02-28          641        1060       Book I
# 4                 305 2023-04-19          123        1058       Book B
# ...               ...        ...          ...         ...          ...
# 10095            5735 2027-03-04           52        1066       Book G
# 10096            5192 2025-08-16          334        1093       Book N
# 10097            5391 2026-06-18          657        1047       Book H
# 10098             861 2034-08-04          579        1014       Book N
# 10099            7271 2029-04-26          153        1052       Book T
#
#        Quantity   Prize  Total Sales Payment Type Customer Age
# ...
